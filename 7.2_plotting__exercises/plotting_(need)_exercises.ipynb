# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='brown', linestyle='dashed',
             marker='o', markerfacecolor='yellow',
             ecolor='black',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.show()

# %%
x=np.array(range(51))

# %%
import math

# %%
math.e
# Out:
# 2.718281828459045

# %%
e=np.e

# %%
sinx=np.sin(x)

# %%
print(sinx)
# Out:
# [ 0.          0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427
#  -0.2794155   0.6569866   0.98935825  0.41211849 -0.54402111 -0.99999021
#  -0.53657292  0.42016704  0.99060736  0.65028784 -0.28790332 -0.96139749
#  -0.75098725  0.14987721  0.91294525  0.83665564 -0.00885131 -0.8462204
#  -0.90557836 -0.13235175  0.76255845  0.95637593  0.27090579 -0.66363388
#  -0.98803162 -0.40403765  0.55142668  0.99991186  0.52908269 -0.42818267
#  -0.99177885 -0.64353813  0.29636858  0.96379539  0.74511316 -0.15862267
#  -0.91652155 -0.83177474  0.01770193  0.85090352  0.90178835  0.12357312
#  -0.76825466 -0.95375265 -0.26237485]

# %%
x1=e**np.divide(-x,10)

# %%
print(x1)
# Out:
# [1.         0.90483742 0.81873075 0.74081822 0.67032005 0.60653066
#  0.54881164 0.4965853  0.44932896 0.40656966 0.36787944 0.33287108
#  0.30119421 0.27253179 0.24659696 0.22313016 0.20189652 0.18268352
#  0.16529889 0.14956862 0.13533528 0.12245643 0.11080316 0.10025884
#  0.09071795 0.082085   0.07427358 0.06720551 0.06081006 0.05502322
#  0.04978707 0.0450492  0.0407622  0.03688317 0.03337327 0.03019738
#  0.02732372 0.02472353 0.02237077 0.02024191 0.01831564 0.01657268
#  0.01499558 0.01356856 0.01227734 0.011109   0.01005184 0.00909528
#  0.00822975 0.00744658 0.00673795]

# %%
y=x1*sinx

# %%
print(y)
# Out:
# [ 0.00000000e+00  7.61394433e-01  7.44469767e-01  1.04544273e-01
#  -5.07299883e-01 -5.81616973e-01 -1.53346477e-01  3.26249890e-01
#   4.44547316e-01  1.67554872e-01 -2.00134182e-01 -3.32867824e-01
#  -1.61612657e-01  1.14508876e-01  2.44280766e-01  1.45098830e-01
#  -5.81266772e-02 -1.75631482e-01 -1.24137357e-01  2.24169273e-02
#   1.23553704e-01  1.02453861e-01 -9.80753025e-04 -8.48410793e-02
#  -8.21522155e-02 -1.08640932e-02  5.66379447e-02  6.42737346e-02
#   1.64737980e-02 -3.65152732e-02 -4.91911980e-02 -1.82015737e-02
#   2.24773669e-02  3.68799165e-02  1.76572193e-02 -1.29299962e-02
#  -2.70990901e-02 -1.59105321e-02  6.62999386e-03  1.95090609e-02
#   1.36472236e-02 -2.62880200e-03 -1.37437693e-02 -1.12859847e-02
#   2.17332551e-04  9.45268431e-03  9.06462835e-03  1.12393179e-03
#  -6.32254153e-03 -7.10219836e-03 -1.76786786e-03]

# %%
x = np.linspace(0, 1, 100)
x=np.array(range(51))
y=x1*sinx
plt.plot(x,y,color='blue')
plt.xlabel('x',fontsize='15',color='darkorange')
plt.ylabel('y',fontsize='15',color='darkorange',rotation=0)
plt.ylim([-1,1])
plt.title('\y=e^-x/10\sin(x)',fontsize='20')
plt.grid(alpha=.25)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Jerome Tay\AppData\Local\Temp\ipykernel_9152\1101920244.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('\mathit{Italic}\y=e^-x/10\sin(x)',fontsize='20')
